# %% [markdown]
# ### This is a learning notebook that accompanies the Coursera course: Applied Data Science Capstone
# This is my work for the Week 1 Peer-graded Assignment

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
